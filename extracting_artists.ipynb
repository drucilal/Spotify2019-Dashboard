# %%
# Ed Sheeran 0uFhZpiffd4h8fcBgw42i1
# Drake
# 100 Percent  5w99BzxT7OOCz2oEkKCReG
# Post Malone
# Michel Bijland 6Myw1PqQ874lA3ZUd6snjE
# Spotify 37i9dQZF1DWSWllk9RmgZM
# Eminmem 
# 100 Percent 7afO1gDW259dyCY3VIoGQ5
# Weekend 
# Amy Leann Aguillon 701T6cSOpzyDpm6oikwL9M
# Spotify 37i9dQZF1DX6bnzK9KPvrz
# # FEMALES
# Ariana Grande 
# Spotify 37i9dQZF1DX1PfYnYcpw8w
# aylin.r.acar 3etgFObeCKF3HqXEnOydIJ

# Rihanna 
# Spotify 37i9dQZF1DWWhBhYl3ZMvY
# mundopap 6J4O8RG68lF3klhYB8Zayt

# Taylor Swift 
# Spotify 37i9dQZF1DX5KpP2LN299J
# Taylor Swift 4GtQVhGjAwcHFz82UKy3Ca

# Sia
# Spotify 37i9dQZF1DX7wWaJYweK28
# Sia 05T1KuTCkjxifLHkawRNVX

# Beyonce 
# Spotify /37i9dQZF1DX2oU49YwtXI2
# Matilda Horn 1aUNSQAvGzXNlwd8L1CJtN

# %%
# import libraries  
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
spotify_client_id = '8b1aedc1ad644e6994896bbee6efc50f'
spotify_client_secret  = '1386635d78fa48b1af2e8e127cc44595'
client_credentials_manager = SpotifyClientCredentials(client_id=spotify_client_id, client_secret=spotify_client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
 # get track ids from playlist
def getPlaylistTrackIDs(user, playlist_id):
        ids = []
        playlist = sp.user_playlist(user, playlist_id)
        for item in playlist['tracks']['items']:
            track = item['track']
            ids.append(track['id'])
        return ids
ids = getPlaylistTrackIDs('Matilda Horn', '1aUNSQAvGzXNlwd8L1CJtN')

# %%
ids
# Out:
# ['1z6WtY7X4HQJvzxC4UgkSf',
#  '42qh86p7TLXyumxSHn65kc',
#  '6JoIs4XLvBgjZOkKnyuPPv',
#  '3axkNosdVQLZiq1HakuGhc',
#  '6Vv9wMxIc6OKRluQefy441',
#  '7cvkXf3AwPGT041PyOi5VX',
#  '76KTeba6u3LfBL4EsCZaTe',
#  '7msV2z3y899aSVTithAkFn',
#  '1pzJboOZaDNwshBnOlNh3a',
#  '3FPUFltTjg6ClUL2wr9ux6',
#  '1uXbwHHfgsXcUKfSZw5ZJ0',
#  '3lBRNqXjPp2j3JMTCXDTNO',
#  '6QFgpUiLoXlmYDjbe0tjyP',
#  '64Tp4KN5U5rtqrasP5a7FH',
#  '72UnWvJ8X67nAzjaHNamYr',
#  '557un1HgwYMuqfWGSTmnxw',
#  '6GQuF9vzJAVs7fYN9ftBdP',
#  '5iaVupGhrGVtwBvmGxxYih',
#  '2CvOqDpQIMw69cCzWqr5yr',
#  '1oQZk2bKBLgP1cbuFKvjkq',
#  '5bpdqm75L1udf8tHR5LCfq',
#  '2wNGoon7FlKnVEyYS1ZRBQ',
#  '7zP67rufQgoODWFI45jntD',
#  '1leG3qAx1fYT1R4CXxxSm4',
#  '7HF0jtuqtQ17b9mCWCKiDR',
#  '3IYsVHWRTHia5lS1LFOIVg',
#  '0O4FbfvKNgmIvM9hE4CitH',
#  '6M9A67YCLVkJ0WxMBbp4Ov',
#  '7M4F4e8lI8Dkod0IEtBx7x',
#  '6UyOsmNg7H1YfR1NYuVvBu',
#  '1gTT2Y987ndPot2Oygq6hn',
#  '6MhQMEASvqkJydrmJiMHtJ',
#  '46QBQSUuGJUBLGhc9KachJ',
#  '5Ia87DeORNfrZDEppvp9rP',
# ...

# %%
def getTrackFeatures(id):
    meta = sp.track(id)
    features = sp.audio_features(id)
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']
    track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
    return track

# %%
# loop over track ids to create dataset
tracks = []
for i in range(0, len(ids)):
    time.sleep(.5)
    track = getTrackFeatures(ids[i])
    tracks.append(track)

df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("beyonce2_catalog.csv", sep = ',')

# %% [markdown]
# Male
# Drake, Ed Sheeran, Post Malone, Eminem, The Weekend
# Female
# Ariana Grande, Rihanna, Taylor Swift, Sia, Beyonce
